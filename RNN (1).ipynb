# %% [markdown]
# # **RNN**

# %%
# !pip install kagglehub
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed, Flatten
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications import ResNet50
import numpy as np
import os
import kagglehub
X, y_labels = load_frames_from_images(image_dataset_path)
unique_labels = np.unique(y_labels)
num_classes = len(unique_labels)
print(f"Number of classes found in training data: {num_classes}")
if len(y_labels) > 0:
    y = tf.keras.utils.to_categorical(
        [np.where(unique_labels == label)[0][0] for label in y_labels],
        num_classes=num_classes
    )
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
    features = base_model.predict(X)
    features = features.reshape(features.shape[0], 1, features.shape[1] * features.shape[2] * features.shape[3])
    rnn_model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(features.shape[1], features.shape[2])),
        LSTM(64),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    rnn_model.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
    rnn_model.fit(features, y, epochs=10, batch_size=10)
    rnn_model.save("rnn_mask_detection.h5")
else:
    print("No labels found. Please check your data loading process.")
# Out:
# ...
# Number of classes found in training data: 853
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step
# Epoch 1/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 62s 272ms/step - accuracy: 0.0000e+00 - loss: 6.7613
# Epoch 2/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - accuracy: 0.0000e+00 - loss: 6.7496
# Epoch 3/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - accuracy: 0.0000e+00 - loss: 6.7514
# Epoch 4/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - accuracy: 0.0032 - loss: 6.7501
# Epoch 5/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 273ms/step - accuracy: 0.0000e+00 - loss: 6.7522
# Epoch 6/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - accuracy: 0.0000e+00 - loss: 6.7507
# Epoch 7/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - accuracy: 0.0000e+00 - loss: 6.7494
# Epoch 8/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 269ms/step - accuracy: 0.0000e+00 - loss: 6.7501
# Epoch 9/10
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - accuracy: 0.0047 - loss: 6.7509
# Epoch 10/10
# ...
